# %%
import pandas as pd
from sklearn import decomposition
import matplotlib.pyplot as plt
import sklearn
import ast
import seaborn as sns
import numpy as np
import statsmodels.formula.api as smf

# %% [markdown]
# # Genre analysis

# %% [markdown]
# Let's import the data set that we are going to use for the analysis in this notebook.

# %%
df_movie = pd.read_csv("Expanded_data/big_data_final.tsv",sep='\t',low_memory=False)

# %% [markdown]
# In the next plot we want to give an idea of the different genres present in the data set.
# Below we display the 20 most present genres.
# We remark that drama, documentary and comedy movies are extremely present compared to other categories such as thriller movies.
# We have to keep this into account when we do our analysis.

# %%
df_genre = df_movie.copy()
df_genre.dropna(subset=['Movie genres names'], inplace=True)
count_genre = df_genre['Movie genres names'].value_counts()
plt.figure(figsize=(15,8))
ax = sns.barplot(x=count_genre.values[0:20], y=count_genre.index[0:20]).set(title='Top 20 genres')
plt.show()

# %% [markdown]
# ### 1) Data preprocessing: creation of dummies for genres

# %% [markdown]
# From the plot above we remark that some categories are actually an ensemble of several categories.
# For example there is the category Commedy & Drama.
# Here we want to split the genres in subunits of single genre.
# This can be done through the help of dummies.

# %% [markdown]
# For the analysis of this section, we are going to focus only on rating, budget and revenue.
# This is way we can only keep these variables.

# %%
data = df_movie[['Movie genres names', 'averageRating', 'inflation corrected budget', 'inflation corrected revenue']].dropna()

# %% [markdown]
# If we recount the total number of movies in each category in the case of dummies, we remark that the total number of categories is 23.
# The drama is leading with more that 2600 movies, followed by comedy and action.

# %%
movie_genres = [ast.literal_eval(movie_genre) for movie_genre in data['Movie genres names']]
pd.Series([genre for sublist in movie_genres for genre in sublist]).value_counts()
# Out:
# Drama          2601
# Comedy         1874
# Action         1395
# Crime          1021
# Romance         905
# Adventure       879
# Thriller        870
# Horror          592
# Mystery         486
# Fantasy         442
# Sci-Fi          431
# Biography       314
# Family          250
# History         177
# Music           167
# Sport           120
# War             106
# Musical          60
# Animation        50
# Western          45
# Documentary      39
# Adult             2
# News              2
# dtype: int64

# %% [markdown]
# Let's create the dummy variables.

# %%
def incorporate_genre_dummies(data):
    # transform into dummies
    movie_genres = [ast.literal_eval(movie_genre) for movie_genre in data['Movie genres names']]
    df = pd.get_dummies(pd.DataFrame(movie_genres))
    df.columns = df.columns.str.split("_").str[-1]

    # need to sum similarly named columns due to unwanted effect of previous computation
    df = df.groupby(level=0, axis=1).sum()
    genre_names = df.columns

    # adding to data and removing old genre column
    data[df.columns] = df.values
    #data = data.drop('Movie genres names', axis = 1)

    # rename problematic Sci-Fi column name
    data.rename(columns={'Sci-Fi' : 'SciFi'}, inplace = True)
    genre_names = [x if x != 'Sci-Fi' else 'SciFi' for x in genre_names]

    return data, genre_names

# %%
data, genre_names = incorporate_genre_dummies(data)

# %% [markdown]
# We rename some variables because of the notation of linear regression that we are going to use later.

# %%
#data.rename(columns={'inflation corrected revenue' : 'corr_revenue', 'inflation corrected budget' : 'corr_budget'}, inplace = True)
data.rename(columns={'Movie genres names' : 'genre','inflation corrected revenue' : 'corr_revenue', 'inflation corrected budget' : 'corr_budget'}, inplace = True)

# %% [markdown]
# Let's add columns for the logarithm of the revenue and budget.

# %%
data['log_revenue'] = np.log(data['corr_revenue'])
data['log_budget'] = np.log(data['corr_budget'])

# %%
data.head(2)
# Out:
#                     genre  averageRating   corr_budget  corr_revenue  Action  \
# 33     ['Crime', 'Drama']            7.6  4.578426e+06  4.692887e+06       0
# 225  ['Action', 'Comedy']            7.0  7.431127e+07  2.694641e+08       1
#
#      Adult  Adventure  Animation  Biography  Comedy  ...  Mystery  News  \
# 33       0          0          0          0       0  ...        0     0
# 225      0          0          0          0       1  ...        0     0
#
#      Romance  SciFi  Sport  Thriller  War  Western  log_revenue  log_budget
# 33         0      0      0         0    0        0    15.361558   15.336866
# 225        0      0      0         0    0        0    19.411946   18.123773
#
# [2 rows x 29 columns]

# %% [markdown]
# ### 2) Genre distribution

# %% [markdown]
# Once we have prepared the dataset for the analysis we want to explore the genre distribution for rating, revenue and budget.

# %% [markdown]
# Below there are some functions that are going to be useful for looking that the distributions.

# %%
def bootstrap(data, n_it):
    means = np.zeros(n_it)
    data = np.array(data)
    
    for n in range(n_it):
        indices = np.random.randint(0, len(data), len(data))
        data_new = data[indices] 
        means[n] = np.nanmean(data_new)
    
    # 95% CI -> 2.5% and 97.5%
    return [np.nanmean(means), np.nanpercentile(means, 2.5),np.nanpercentile(means, 97.5)]

def plot_CIs(CIs, params):
    # function to plot confidence intervals
    # adapted code from solutions of tutorial 4

    # Compute interval center and half interval length for plotting
    means = np.array([CI[0] for CI in CIs])
    one_sided_CI = np.array([(CI[2] - CI[1]) / 2 for CI in CIs])

    # plot CIs
    plt.figure(figsize=(8,5))
    plt.errorbar(means, np.array(range(len(means))), xerr=one_sided_CI, linewidth=1,
                 linestyle='none', marker='o', markersize=3,
                 markerfacecolor='black', markeredgecolor='black', capsize=5)
    #plt.vlines(0, 0, len(means), linestyle='--')
    plt.yticks(range(len(params)), params);
    plt.title('95% confidence intervals')
    plt.show()
    
def difference_in_usage(data_, g, CI_list, measure) :
    #difference returns -1 (absent for winner and present for the loser), 0 (present or absent in both), or 1 (present for the winner and absent for looser). 
    d = data_[data_[g]==1][measure]
    b = bootstrap(d, 1000)
    CI_list.append(b)

# %% [markdown]
# #### 2.1) Distribution of the rating across genre

# %%
fig, axs = plt.subplots(6,4, constrained_layout=True, figsize=(20, 20))
fig.suptitle('Rating distribution for each genre')

axs[0,0].hist(data.averageRating, density=True)
axs[0,0].set_title('All genres')
axs[0,0].set_xlim(0,10)
for i, g in enumerate(genre_names):
    i = i+1
    ax = axs[int(i/4),i%4]
    ax.hist(data[data[g]==1].averageRating, density=True)
    ax.set_title(g)
    ax.set_xlim(0,10)

# %% [markdown]
# We remark that in general the distributions seem to be heavy-tailed, with their maximum towords more positive rating.
# We remind that the rating are in the range $[0,10]$, where $10$ is the maximum.

# %% [markdown]
# By looking that the plot of the mean value with the respecting 95% confidence interval, we see that some genres have mean value significantly different from each other.
# Biography, news, war and wester seems to have higher mean values that the other categories.

# %%
CIs = []    
    
for g in genre_names:
    difference_in_usage(data, g=g, CI_list=CIs, measure='averageRating')
    
plot_CIs(CIs, genre_names)

# %% [markdown]
# #### 2.2) Distribution of the budget across genre

# %%
fig, axs = plt.subplots(6,4, constrained_layout=True, figsize=(20, 20))
fig.suptitle('Budget distribution from each genre (logarithm)')

axs[0,0].hist(data.log_budget, density=True)
axs[0,0].set_title('All genres')
axs[0,0].set_xlim(0,21)
for i, g in enumerate(genre_names):
    i = i+1
    ax = axs[int(i/4),i%4]
    ax.hist(data[data[g]==1].log_budget, density=True)
    ax.set_title(g)
    ax.set_xlim(0,21)

# %%
CIs = []
for g in genre_names:
    difference_in_usage(data, g=g, CI_list=CIs, measure='log_budget')
    
plot_CIs(CIs, genre_names)

# %% [markdown]
# If we look that the mean value of the log budget, we remark that news, documentary and adult movies have low budgetcompared to all the others.

# %% [markdown]
# #### 2.3) Distribution of the revenue across genre

# %%
fig, axs = plt.subplots(6,4, constrained_layout=True, figsize=(20, 20))
fig.suptitle('Revenue distribution from each genre (logarithm)')

axs[0,0].hist(data.log_revenue, density=True)
axs[0,0].set_title('All genres')
axs[0,0].set_xlim(0,27)
for i, g in enumerate(genre_names):
    i = i+1
    ax = axs[int(i/4),i%4]
    ax.hist(data[data[g]==1].log_revenue, density=True)
    ax.set_title(g)
    ax.set_xlim(0,27)

# %%
CIs = []
for g in genre_names:
    difference_in_usage(data, g=g, CI_list=CIs, measure='log_revenue')
    
plot_CIs(CIs, genre_names)

# %% [markdown]
# Adult movies seem to have extremely high revenue.
# We also have to remember that the adult category had a very low budget. It seems that this genre can make a lot of money with a low budget. But from the rating analysis it was not the best rated category.

# %% [markdown]
# Let's now try to perform some linear regressions in order to predict our variables of interest, rating and revenue, with the help of the genre and the budget.

# %% [markdown]
# ### 3) Linear regression: average ratings and revenue

# %% [markdown]
# Here we create a function that is going to be useful for the visualisation of the coefficient of the linear regressions.

# %%
def barplot(res, figsize=(5,7)) :
    ''' Barplot of the coefficients of the linear regression sorted by value'''
    tmp = []
    for name, value in zip(res.params.index, res.params):
        tmp.append({"name": name, "value": value})

    features_coef = pd.DataFrame(tmp).sort_values("value")

    plt.subplots(figsize=figsize)
    plt.barh(features_coef.name, features_coef.value, alpha=0.6)
    plt.show()

# %% [markdown]
# #### 3.1) Rating in function of the genres

# %% [markdown]
# We want to try to linearly predict the rating based on the genre.

# %%
mod = smf.ols(formula="averageRating ~ Action + Adult + Adventure +\
       Animation + Biography + Comedy + Crime + Documentary + Drama +\
       Family + Fantasy + History + Horror + Music + Musical + Mystery +\
       News + Romance + SciFi + Sport + Thriller + War + Western", data=data)

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          averageRating   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                  0.154
# Method:                 Least Squares   F-statistic:                     40.80
# Date:                Wed, 07 Dec 2022   Prob (F-statistic):          3.06e-167
# Time:                        15:40:38   Log-Likelihood:                -6939.2
# No. Observations:                5018   AIC:                         1.393e+04
# Df Residuals:                    4994   BIC:                         1.408e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       6.4052      0.061    105.469      0.000       6.286       6.524
# Action         -0.2135      0.039     -5.449      0.000      -0.290      -0.137
# Adult          -0.3969      0.685     -0.580      0.562      -1.739       0.945
# Adventure       0.0691      0.044      1.552      0.121      -0.018       0.156
# Animation      -0.2798      0.141     -1.981      0.048      -0.557      -0.003
# Biography       0.3434      0.062      5.568      0.000       0.222       0.464
# Comedy         -0.2810      0.040     -6.985      0.000      -0.360      -0.202
# Crime           0.0363      0.040      0.913      0.361      -0.042       0.114
# Documentary     0.3975      0.165      2.407      0.016       0.074       0.721
# Drama           0.4677      0.038     12.369      0.000       0.394       0.542
# Family         -0.4126      0.067     -6.132      0.000      -0.544      -0.281
# Fantasy        -0.1034      0.052     -1.981      0.048      -0.206      -0.001
# History        -0.0899      0.079     -1.145      0.252      -0.244       0.064
# Horror         -0.4858      0.052     -9.318      0.000      -0.588      -0.384
# Music          -0.0715      0.079     -0.904      0.366      -0.227       0.084
# Musical         0.1021      0.127      0.804      0.421      -0.147       0.351
# Mystery         0.0033      0.051      0.065      0.948      -0.096       0.103
# News            0.3256      0.703      0.463      0.643      -1.052       1.703
# Romance        -0.1699      0.042     -4.052      0.000      -0.252      -0.088
# SciFi           0.0655      0.055      1.199      0.230      -0.042       0.173
# Sport          -0.0932      0.092     -1.011      0.312      -0.274       0.088
# Thriller       -0.0321      0.044     -0.732      0.464      -0.118       0.054
# War             0.2193      0.098      2.236      0.025       0.027       0.412
# Western         0.4824      0.147      3.271      0.001       0.193       0.771
# ==============================================================================
# Omnibus:                      547.394   Durbin-Watson:                   1.902
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              998.532
# Skew:                          -0.730   Prob(JB):                    1.48e-217
# Kurtosis:                       4.626   Cond. No.                         67.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
barplot(res)

# %% [markdown]
# **Biography, Documentary, Drama, Western** are significantly driving the grades upwards, while **Action, Comedy, Family, Horror and Romance** drive it downwards.
# We have to remark that the R square of this regression is very low, not even 0.2. The model does not describe well our response variable.

# %% [markdown]
# But what if we keep the genre together without using dummies varibles?

# %%
mod = smf.ols(formula="averageRating ~ genre", data=data)

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          averageRating   R-squared:                       0.258
# Model:                            OLS   Adj. R-squared:                  0.202
# Method:                 Least Squares   F-statistic:                     4.602
# Date:                Wed, 07 Dec 2022   Prob (F-statistic):          9.26e-132
# Time:                        15:55:40   Log-Likelihood:                -6621.4
# No. Observations:                5018   AIC:                         1.395e+04
# Df Residuals:                    4664   BIC:                         1.626e+04
# Df Model:                         353
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            5.9583      0.271     21.979      0.000       5.427       6.490
# genre[T.['Action', 'Adventure', 'Biography']]        0.8167      0.542      1.506      0.132      -0.246       1.880
# genre[T.['Action', 'Adventure', 'Comedy']]           0.0867      0.285      0.304      0.761      -0.473       0.646
# genre[T.['Action', 'Adventure', 'Crime']]           -0.3433      0.343     -1.001      0.317      -1.016       0.329
# genre[T.['Action', 'Adventure', 'Drama']]            0.7759      0.292      2.660      0.008       0.204       1.348
# genre[T.['Action', 'Adventure', 'Family']]          -0.4038      0.392     -1.030      0.303      -1.172       0.365
# genre[T.['Action', 'Adventure', 'Fantasy']]         -0.0522      0.290     -0.180      0.857      -0.621       0.517
# genre[T.['Action', 'Adventure', 'History']]          0.0417      0.717      0.058      0.954      -1.364       1.448
# genre[T.['Action', 'Adventure', 'Horror']]          -0.4429      0.376     -1.178      0.239      -1.180       0.294
# genre[T.['Action', 'Adventure', 'Mystery']]          0.3917      0.402      0.974      0.330      -0.397       1.180
# genre[T.['Action', 'Adventure', 'Romance']]         -0.0333      0.542     -0.061      0.951      -1.096       1.030
# genre[T.['Action', 'Adventure', 'Sci-Fi']]           0.5049      0.285      1.774      0.076      -0.053       1.063
# genre[T.['Action', 'Adventure', 'Thriller']]         0.5401      0.296      1.823      0.068      -0.041       1.121
# genre[T.['Action', 'Adventure', 'War']]              1.6917      0.717      2.359      0.018       0.286       3.098
# genre[T.['Action', 'Adventure', 'Western']]          0.5917      0.542      1.091      0.275      -0.471       1.655
# genre[T.['Action', 'Adventure']]                     0.2517      0.402      0.626      0.531      -0.537       1.040
# genre[T.['Action', 'Biography', 'Crime']]            1.1417      0.414      2.757      0.006       0.330       1.954
# genre[T.['Action', 'Biography', 'Drama']]            1.3350      0.364      3.670      0.000       0.622       2.048
# genre[T.['Action', 'Biography', 'Western']]         -0.1583      0.977     -0.162      0.871      -2.075       1.758
# genre[T.['Action', 'Comedy', 'Crime']]               0.2132      0.288      0.741      0.459      -0.351       0.777
# genre[T.['Action', 'Comedy', 'Documentary']]         0.9083      0.606      1.498      0.134      -0.280       2.097
# genre[T.['Action', 'Comedy', 'Drama']]              -0.3917      0.470     -0.834      0.404      -1.312       0.529
# genre[T.['Action', 'Comedy', 'Family']]             -1.2083      0.542     -2.229      0.026      -2.271      -0.145
# genre[T.['Action', 'Comedy', 'Fantasy']]             0.1750      0.414      0.423      0.673      -0.637       0.987
# genre[T.['Action', 'Comedy', 'History']]            -1.0583      0.977     -1.083      0.279      -2.975       0.858
# genre[T.['Action', 'Comedy', 'Horror']]              0.1508      0.392      0.385      0.701      -0.618       0.919
# genre[T.['Action', 'Comedy', 'Music']]              -2.4583      0.977     -2.515      0.012      -4.375      -0.542
# genre[T.['Action', 'Comedy', 'Mystery']]             1.8417      0.977      1.884      0.060      -0.075       3.758
# genre[T.['Action', 'Comedy', 'Romance']]            -0.0155      0.447     -0.035      0.972      -0.891       0.860
# genre[T.['Action', 'Comedy', 'Sci-Fi']]             -0.6883      0.402     -1.712      0.087      -1.477       0.100
# genre[T.['Action', 'Comedy', 'Sport']]               0.2417      0.977      0.247      0.805      -1.675       2.158
# genre[T.['Action', 'Comedy', 'Thriller']]            0.2917      0.542      0.538      0.591      -0.771       1.355
# genre[T.['Action', 'Comedy', 'War']]                 0.4417      0.717      0.616      0.538      -0.964       1.848
# genre[T.['Action', 'Comedy']]                        0.2350      0.364      0.646      0.518      -0.478       0.948
# genre[T.['Action', 'Crime', 'Drama']]                0.5450      0.282      1.935      0.053      -0.007       1.097
# genre[T.['Action', 'Crime', 'Fantasy']]             -0.6383      0.500     -1.277      0.202      -1.618       0.342
# genre[T.['Action', 'Crime', 'Horror']]               0.2750      0.470      0.586      0.558      -0.646       1.196
# genre[T.['Action', 'Crime', 'Mystery']]             -0.2083      0.542     -0.384      0.701      -1.271       0.855
# genre[T.['Action', 'Crime', 'Romance']]             -1.0583      0.717     -1.476      0.140      -2.464       0.348
# genre[T.['Action', 'Crime', 'Sci-Fi']]               0.1333      0.383      0.348      0.728      -0.618       0.885
# genre[T.['Action', 'Crime', 'Thriller']]             0.5623      0.288      1.951      0.051      -0.003       1.127
# genre[T.['Action', 'Crime']]                        -0.8983      0.500     -1.797      0.072      -1.878       0.082
# genre[T.['Action', 'Drama', 'Family']]              -0.1333      0.542     -0.246      0.806      -1.196       0.930
# genre[T.['Action', 'Drama', 'Fantasy']]             -0.4472      0.414     -1.080      0.280      -1.259       0.365
# genre[T.['Action', 'Drama', 'History']]              0.9448      0.318      2.972      0.003       0.322       1.568
# genre[T.['Action', 'Drama', 'Horror']]              -0.8083      0.542     -1.491      0.136      -1.871       0.255
# genre[T.['Action', 'Drama', 'Music']]                0.3417      0.977      0.350      0.727      -1.575       2.258
# genre[T.['Action', 'Drama', 'Mystery']]              1.4274      0.447      3.196      0.001       0.552       2.303
# genre[T.['Action', 'Drama', 'Romance']]              0.6717      0.402      1.670      0.095      -0.117       1.460
# genre[T.['Action', 'Drama', 'Sci-Fi']]               0.7008      0.337      2.079      0.038       0.040       1.361
# genre[T.['Action', 'Drama', 'Sport']]                0.3780      0.392      0.964      0.335      -0.390       1.147
# genre[T.['Action', 'Drama', 'Thriller']]             0.3254      0.307      1.061      0.289      -0.276       0.926
# genre[T.['Action', 'Drama', 'War']]                  0.7017      0.343      2.046      0.041       0.029       1.374
# genre[T.['Action', 'Drama', 'Western']]              1.9417      0.977      1.986      0.047       0.025       3.858
# genre[T.['Action', 'Drama']]                         0.5917      0.359      1.650      0.099      -0.111       1.295
# genre[T.['Action', 'Family', 'Fantasy']]            -1.8583      0.977     -1.901      0.057      -3.775       0.058
# genre[T.['Action', 'Family', 'Sport']]               0.1417      0.977      0.145      0.885      -1.775       2.058
# genre[T.['Action', 'Fantasy', 'Horror']]             0.0345      0.369      0.093      0.926      -0.690       0.759
# genre[T.['Action', 'Fantasy', 'Romance']]           -1.5583      0.977     -1.594      0.111      -3.475       0.358
# genre[T.['Action', 'Fantasy', 'Sci-Fi']]            -1.0583      0.977     -1.083      0.279      -2.975       0.858
# genre[T.['Action', 'Fantasy', 'Thriller']]          -0.3155      0.447     -0.706      0.480      -1.191       0.560
# genre[T.['Action', 'Fantasy', 'Western']]            0.2417      0.977      0.247      0.805      -1.675       2.158
# genre[T.['Action', 'History']]                       0.9417      0.977      0.963      0.335      -0.975       2.858
# genre[T.['Action', 'Horror', 'Mystery']]             0.3417      0.606      0.564      0.573      -0.847       1.530
# genre[T.['Action', 'Horror', 'Sci-Fi']]             -0.1422      0.319     -0.445      0.656      -0.768       0.484
# genre[T.['Action', 'Horror', 'Thriller']]            0.2250      0.470      0.479      0.632      -0.696       1.146
# genre[T.['Action', 'Horror']]                        0.5417      0.717      0.755      0.450      -0.864       1.948
# genre[T.['Action', 'Mystery', 'Romance']]           -0.4583      0.977     -0.469      0.639      -2.375       1.458
# genre[T.['Action', 'Mystery', 'Sci-Fi']]             0.5292      0.429      1.235      0.217      -0.311       1.370
# genre[T.['Action', 'Mystery', 'Thriller']]           0.9000      0.383      2.347      0.019       0.148       1.652
# genre[T.['Horror']]                                 -0.2539      0.305     -0.832      0.405      -0.852       0.344
# genre[T.['Musical', 'Romance']]                     -0.3583      0.977     -0.367      0.714      -2.275       1.558
# genre[T.['Musical']]                                -2.6583      0.977     -2.720      0.007      -4.575      -0.742
# genre[T.['Mystery', 'Romance', 'Thriller']]         -0.1583      0.977     -0.162      0.871      -2.075       1.758
# genre[T.['Mystery', 'Sci-Fi', 'Thriller']]           1.4417      0.606      2.378      0.017       0.253       2.630
# genre[T.['Mystery', 'Thriller']]                     0.9317      0.402      2.317      0.021       0.143       1.720
# genre[T.['Romance', 'Sci-Fi']]                       1.0417      0.977      1.066      0.287      -0.875       2.958
# genre[T.['Romance', 'Thriller']]                    -0.5583      0.977     -0.571      0.568      -2.475       1.358
# genre[T.['Romance']]                                -2.1583      0.717     -3.009      0.003      -3.564      -0.752
# genre[T.['Sci-Fi', 'Thriller']]                      0.5417      0.500      1.084      0.279      -0.438       1.522
# genre[T.['Thriller']]                                0.5861      0.414      1.415      0.157      -0.226       1.398
# genre[T.['Western']]                                 1.8217      0.500      3.644      0.000       0.842       2.802
# ==============================================================================
# Omnibus:                      375.063   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              629.084
# Skew:                          -0.563   Prob(JB):                    2.49e-137
# Kurtosis:                       4.319   Cond. No.                         391.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# We obtain a higher R squre! The genre not split better capture the rating!

# %% [markdown]
# #### 3.2) Log revenue in function of the genre

# %% [markdown]
# We can perform the same analysis of before but the the logarithm of the revenue as response variable.
# The result is presented below.

# %%
mod = smf.ols(formula="log_revenue ~ Action + Adult + Adventure + \
       Animation + Biography + Comedy + Crime + Documentary + Drama +\
       Family + Fantasy + History + Horror + Music + Musical + Mystery +\
       News + Romance + SciFi + Sport + Thriller + War + Western", data=data)

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log_revenue   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     19.29
# Date:                Thu, 01 Dec 2022   Prob (F-statistic):           8.11e-76
# Time:                        16:10:31   Log-Likelihood:                -10458.
# No. Observations:                5024   AIC:                         2.096e+04
# Df Residuals:                    5000   BIC:                         2.112e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      17.0097      0.122    139.371      0.000      16.770      17.249
# Action          0.6843      0.079      8.694      0.000       0.530       0.839
# Adult           2.6685      1.377      1.938      0.053      -0.031       5.368
# Adventure       0.6196      0.089      6.934      0.000       0.444       0.795
# Animation      -0.8649      0.281     -3.073      0.002      -1.417      -0.313
# Biography       0.5287      0.124      4.264      0.000       0.286       0.772
# Comedy          0.1596      0.081      1.974      0.048       0.001       0.318
# Crime          -0.1430      0.080     -1.790      0.074      -0.300       0.014
# Documentary    -1.5119      0.332     -4.553      0.000      -2.163      -0.861
# Drama          -0.2837      0.076     -3.734      0.000      -0.433      -0.135
# Family          0.6229      0.135      4.605      0.000       0.358       0.888
# Fantasy         0.2397      0.105      2.285      0.022       0.034       0.445
# History         0.1087      0.158      0.689      0.491      -0.201       0.418
# Horror         -0.4000      0.105     -3.818      0.000      -0.605      -0.195
# Music           0.2305      0.159      1.448      0.148      -0.081       0.543
# Musical         0.7110      0.255      2.783      0.005       0.210       1.212
# Mystery         0.4362      0.102      4.271      0.000       0.236       0.636
# News            0.9637      1.413      0.682      0.495      -1.807       3.735
# Romance         0.2767      0.084      3.282      0.001       0.111       0.442
# SciFi           0.3554      0.110      3.238      0.001       0.140       0.571
# Sport           0.4086      0.185      2.204      0.028       0.045       0.772
# Thriller        0.4163      0.088      4.720      0.000       0.243       0.589
# War             0.1792      0.197      0.909      0.364      -0.207       0.566
# Western         0.5568      0.297      1.878      0.060      -0.025       1.138
# ==============================================================================
# Omnibus:                     1122.570   Durbin-Watson:                   1.866
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3111.784
# Skew:                          -1.178   Prob(JB):                         0.00
# Kurtosis:                       6.052   Cond. No.                         67.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
barplot(res)

# %% [markdown]
# **Action, Adventure, Biography, Family, Mystery, Thriller** are significantly driving the revenue upwards, while **Animation, Documentary, Drama and Horror** drive it downwards.
# Again the R squared is very low, even lower than for the case of the rating.
# This model does not predict our response variable.
#
# It seems that the genre is not helpful to linearly predict the rating and the log revenue.
#
# Some genres have a similar effect on rating and revenue, like **Biography (upward) and Horror (downward)**. While **Action** movies are generally associated to a bad movie, it paradoxically generates a lot of revenue. On the contrary, while **Documentaries** are well graded, they produce little revenue.
# Let's try to captue this in one regression using interactions.

# %%
mod = smf.ols(formula="log_revenue ~ Comedy*Romance + \
                                    Comedy*Drama + \
                                    Drama*Romance ", data=data)

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log_revenue   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     21.39
# Date:                Thu, 01 Dec 2022   Prob (F-statistic):           6.07e-25
# Time:                        16:10:31   Log-Likelihood:                -10608.
# No. Observations:                5024   AIC:                         2.123e+04
# Df Residuals:                    5017   BIC:                         2.128e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         17.9072      0.058    308.306      0.000      17.793      18.021
# Comedy            -0.3599      0.086     -4.193      0.000      -0.528      -0.192
# Romance           -0.7040      0.209     -3.371      0.001      -1.113      -0.295
# Comedy:Romance     0.7887      0.181      4.346      0.000       0.433       1.145
# Drama             -0.6710      0.076     -8.822      0.000      -0.820      -0.522
# Comedy:Drama       0.0906      0.135      0.671      0.502      -0.174       0.355
# Drama:Romance      0.4448      0.190      2.336      0.020       0.072       0.818
# ==============================================================================
# Omnibus:                     1178.051   Durbin-Watson:                   1.855
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3466.320
# Skew:                          -1.213   Prob(JB):                         0.00
# Kurtosis:                       6.268   Cond. No.                         14.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
barplot(res, figsize=(3,5))

# %% [markdown]
# Interestingly, for very common genre associations, we observe that their combination has a positive effect on revenue, while the genre alone tend to provoke a decrease. But the R value decreased.

# %% [markdown]
# Again let's try to use the original genres:

# %%
mod = smf.ols(formula="log_revenue ~ genre ", data=data)

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log_revenue   R-squared:                       0.170
# Model:                            OLS   Adj. R-squared:                  0.108
# Method:                 Least Squares   F-statistic:                     2.713
# Date:                Wed, 07 Dec 2022   Prob (F-statistic):           6.62e-50
# Time:                        15:58:45   Log-Likelihood:                -10169.
# No. Observations:                5018   AIC:                         2.105e+04
# Df Residuals:                    4664   BIC:                         2.335e+04
# Df Model:                         353
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                           17.6075      0.550     32.029      0.000      16.530      18.685
# genre[T.['Action', 'Adventure', 'Biography']]        0.6673      1.099      0.607      0.544      -1.488       2.823
# genre[T.['Action', 'Adventure', 'Comedy']]           0.6843      0.579      1.182      0.237      -0.450       1.819
# genre[T.['Action', 'Adventure', 'Crime']]            0.1749      0.695      0.251      0.801      -1.188       1.538
# genre[T.['Action', 'Adventure', 'Drama']]            0.9213      0.592      1.557      0.119      -0.238       2.081
# genre[T.['Action', 'Adventure', 'Family']]           0.8487      0.795      1.068      0.286      -0.710       2.407
# genre[T.['Action', 'Adventure', 'Fantasy']]          0.9413      0.589      1.599      0.110      -0.213       2.095
# genre[T.['Action', 'Adventure', 'History']]          0.2617      1.454      0.180      0.857      -2.590       3.113
# genre[T.['Action', 'Adventure', 'Horror']]           0.1346      0.762      0.177      0.860      -1.360       1.629
# genre[T.['Action', 'Adventure', 'Mystery']]          0.4495      0.815      0.551      0.581      -1.149       2.048
# genre[T.['Action', 'Adventure', 'Romance']]          1.1434      1.099      1.040      0.298      -1.012       3.299
# genre[T.['Action', 'Adventure', 'Sci-Fi']]           1.3685      0.577      2.371      0.018       0.237       2.500
# genre[T.['Action', 'Adventure', 'Thriller']]         1.6739      0.601      2.787      0.005       0.496       2.851
# genre[T.['Action', 'Adventure', 'War']]              1.1685      1.454      0.803      0.422      -1.683       4.020
# genre[T.['Action', 'Adventure', 'Western']]          0.5089      1.099      0.463      0.643      -1.647       2.664
# genre[T.['Action', 'Adventure']]                     0.9936      0.815      1.219      0.223      -0.605       2.592
# genre[T.['Action', 'Biography', 'Crime']]           -0.0673      0.840     -0.080      0.936      -1.714       1.579
# genre[T.['Action', 'Biography', 'Drama']]            0.6160      0.738      0.835      0.404      -0.830       2.062
# genre[T.['Action', 'Biography', 'Western']]         -2.4427      1.982     -1.232      0.218      -6.328       1.443
# genre[T.['Action', 'Comedy', 'Crime']]               0.2683      0.583      0.460      0.646      -0.875       1.412
# genre[T.['Action', 'Comedy', 'Documentary']]         1.1661      1.229      0.949      0.343      -1.244       3.576
# genre[T.['Action', 'Comedy', 'Drama']]              -0.6310      0.952     -0.663      0.508      -2.498       1.236
# genre[T.['Action', 'Comedy', 'Family']]             -1.6770      1.099     -1.525      0.127      -3.832       0.479
# genre[T.['Action', 'Comedy', 'Fantasy']]             0.0574      0.840      0.068      0.946      -1.589       1.704
# genre[T.['Action', 'Comedy', 'History']]            -3.2514      1.982     -1.640      0.101      -7.137       0.634
# genre[T.['Action', 'Comedy', 'Horror']]             -1.9715      0.795     -2.480      0.013      -3.530      -0.413
# genre[T.['Action', 'Comedy', 'Music']]              -0.1104      1.982     -0.056      0.956      -3.996       3.775
# genre[T.['Action', 'Comedy', 'Mystery']]            -0.3615      1.982     -0.182      0.855      -4.247       3.524
# genre[T.['Action', 'Comedy', 'Romance']]            -1.9929      0.906     -2.200      0.028      -3.768      -0.217
# genre[T.['Action', 'Comedy', 'Sci-Fi']]             -0.2152      0.815     -0.264      0.792      -1.814       1.383
# genre[T.['Action', 'Comedy', 'Sport']]               2.6261      1.982      1.325      0.185      -1.260       6.512
# genre[T.['Action', 'Comedy', 'Thriller']]           -0.1962      1.099     -0.178      0.858      -2.352       1.959
# genre[T.['Action', 'Comedy', 'War']]                 0.7581      1.454      0.521      0.602      -2.093       3.610
# genre[T.['Action', 'Comedy']]                       -0.0782      0.738     -0.106      0.916      -1.524       1.368
# genre[T.['Action', 'Crime', 'Drama']]               -0.2845      0.571     -0.498      0.618      -1.404       0.835
# genre[T.['Action', 'Crime', 'Fantasy']]              0.3943      1.014      0.389      0.697      -1.593       2.382
# genre[T.['Action', 'Crime', 'Horror']]              -1.5755      0.952     -1.655      0.098      -3.442       0.291
# genre[T.['Action', 'Crime', 'Mystery']]              0.2765      1.099      0.251      0.801      -1.879       2.432
# genre[T.['Action', 'Crime', 'Romance']]             -2.6047      1.454     -1.791      0.073      -5.456       0.247
# genre[T.['Action', 'Crime', 'Sci-Fi']]               0.1862      0.777      0.240      0.811      -1.338       1.710
# genre[T.['Action', 'Crime', 'Thriller']]             0.6144      0.584      1.051      0.293      -0.531       1.760
# genre[T.['Action', 'Crime']]                        -0.1981      1.014     -0.195      0.845      -2.185       1.789
# genre[T.['Action', 'Drama', 'Family']]               1.0525      1.099      0.957      0.338      -1.103       3.208
# genre[T.['Action', 'Drama', 'Fantasy']]              0.8234      0.840      0.981      0.327      -0.823       2.470
# genre[T.['Action', 'Drama', 'History']]             -0.0908      0.645     -0.141      0.888      -1.355       1.173
# genre[T.['Action', 'Drama', 'Horror']]              -2.1116      1.099     -1.921      0.055      -4.267       0.044
# genre[T.['Action', 'Drama', 'Music']]                2.8847      1.982      1.455      0.146      -1.001       6.771
# genre[T.['Action', 'Drama', 'Mystery']]              0.5582      0.906      0.616      0.538      -1.217       2.334
# genre[T.['Action', 'Drama', 'Romance']]             -0.3298      0.815     -0.404      0.686      -1.928       1.269
# genre[T.['Action', 'Drama', 'Sci-Fi']]               0.4077      0.683      0.597      0.551      -0.932       1.747
# genre[T.['Action', 'Drama', 'Sport']]                0.2025      0.795      0.255      0.799      -1.356       1.761
# genre[T.['Action', 'Drama', 'Thriller']]             0.4189      0.622      0.674      0.501      -0.800       1.638
# genre[T.['Action', 'Drama', 'War']]                 -1.1779      0.695     -1.694      0.090      -2.541       0.185
# genre[T.['Action', 'Drama', 'Western']]             -0.3717      1.982     -0.188      0.851      -4.258       3.514
# genre[T.['Action', 'Drama']]                         0.5717      0.727      0.786      0.432      -0.854       1.997
# genre[T.['Action', 'Family', 'Fantasy']]            -0.8021      1.982     -0.405      0.686      -4.688       3.084
# genre[T.['Action', 'Family', 'Sport']]               1.8589      1.982      0.938      0.348      -2.027       5.745
# genre[T.['Action', 'Fantasy', 'Horror']]            -0.0788      0.749     -0.105      0.916      -1.548       1.390
# genre[T.['Action', 'Fantasy', 'Romance']]           -0.6785      1.982     -0.342      0.732      -4.564       3.207
# genre[T.['Action', 'Fantasy', 'Sci-Fi']]            -1.4082      1.982     -0.710      0.477      -5.294       2.478
# genre[T.['Action', 'Fantasy', 'Thriller']]           0.2751      0.906      0.304      0.761      -1.500       2.051
# genre[T.['Action', 'Fantasy', 'Western']]           -1.1689      1.982     -0.590      0.555      -5.055       2.717
# genre[T.['Action', 'History']]                      -0.2867      1.982     -0.145      0.885      -4.173       3.599
# genre[T.['Action', 'Horror', 'Mystery']]            -1.6105      1.229     -1.310      0.190      -4.020       0.799
# genre[T.['Crime', 'Drama', 'Music']]                -1.2668      1.014     -1.250      0.211      -3.254       0.720
# genre[T.['Crime', 'Drama', 'Musical']]              -0.3504      1.229     -0.285      0.776      -2.760       2.060
# genre[T.['Crime', 'Drama', 'Mystery']]              -0.2674      0.585     -0.457      0.648      -1.414       0.879
# genre[T.['Crime', 'Drama', 'Romance']]              -1.0681      0.673     -1.586      0.113      -2.388       0.252
# genre[T.['Crime', 'Drama', 'Sci-Fi']]               -1.1420      1.982     -0.576      0.565      -5.028       2.744
# genre[T.['Crime', 'Drama', 'Sport']]                -0.0459      1.982     -0.023      0.982      -3.932       3.840
# genre[T.['Crime', 'Drama', 'Thriller']]             -0.6617      0.581     -1.140      0.254      -1.800       0.477
# genre[T.['Crime', 'Drama', 'Western']]              -1.8550      1.982     -0.936      0.349      -5.741       2.031
# genre[T.['Crime', 'Drama']]                         -1.1698      0.601     -1.948      0.052      -2.347       0.008
# genre[T.['Crime', 'Fantasy', 'Horror']]              0.4044      1.982      0.204      0.838      -3.481       4.290
# genre[T.['Crime', 'Horror', 'Mystery']]             -0.9427      0.840     -1.123      0.262      -2.589       0.704
# genre[T.['Crime', 'Horror', 'Sci-Fi']]               1.3073      1.982      0.660      0.510      -2.579       5.193
# genre[T.['Crime', 'Horror', 'Thriller']]            -0.4648      0.869     -0.535      0.593      -2.169       1.239
# genre[T.['Crime', 'Horror', 'Western']]             -0.4997      1.982     -0.252      0.801      -4.386       3.386
# genre[T.['Crime', 'Horror']]                        -1.3763      1.982     -0.694      0.487      -5.262       2.509
# genre[T.['Crime', 'Mystery', 'Romance']]            -1.7400      1.982     -0.878      0.380      -5.626       2.146
# genre[T.['Crime', 'Mystery', 'Thriller']]           -0.6301      0.678     -0.929      0.353      -1.960       0.699
# genre[T.['Crime', 'Romance', 'Thriller']]            1.5173      1.982      0.766      0.444      -2.369       5.403
# genre[T.['Crime', 'Sci-Fi']]                         1.3894      1.982      0.701      0.483      -2.496       5.275
# genre[T.['Crime', 'Thriller']]                      -0.8793      0.683     -1.287      0.198      -2.219       0.460
# genre[T.['Documentary', 'Drama', 'Music']]           2.0068      1.982      1.012      0.311      -1.879       5.893
# genre[T.['Documentary', 'Drama', 'Sport']]          -0.7206      1.982     -0.364      0.716      -4.606       3.165
# genre[T.['Documentary', 'Drama', 'War']]             1.9734      1.982      0.996      0.319      -1.912       5.859
# genre[T.['Documentary', 'Drama']]                   -2.4597      1.454     -1.691      0.091      -5.311       0.392
# genre[T.['Documentary', 'Family']]                   1.3828      1.982      0.698      0.485      -2.503       5.269
# genre[T.['Documentary', 'History']]                 -1.8461      1.982     -0.931      0.352      -5.732       2.040
# genre[T.['Documentary', 'Music']]                   -1.1157      0.952     -1.172      0.241      -2.982       0.751
# genre[T.['Documentary', 'News']]                     0.4109      1.982      0.207      0.836      -3.475       4.297
# genre[T.['Documentary', 'Sport']]                   -2.9047      1.982     -1.465      0.143      -6.791       0.981
# genre[T.['Documentary']]                            -2.8511      0.815     -3.497      0.000      -4.450      -1.253
# genre[T.['Fantasy', 'Horror', 'Thriller']]           0.2664      0.952      0.280      0.780      -1.600       2.133
# genre[T.['Fantasy', 'Horror']]                      -0.0022      0.777     -0.003      0.998      -1.526       1.522
# genre[T.['Fantasy', 'Musical', 'Romance']]           0.5235      1.982      0.264      0.792      -3.362       4.409
# genre[T.['Fantasy', 'Mystery', 'Romance']]           1.9487      1.982      0.983      0.326      -1.937       5.835
# genre[T.['Fantasy', 'Mystery', 'Sci-Fi']]            0.0195      1.982      0.010      0.992      -3.866       3.905
# genre[T.['Horror', 'Mystery', 'Sci-Fi']]            -2.0296      0.795     -2.553      0.011      -3.588      -0.471
# genre[T.['Horror', 'Mystery', 'Thriller']]           0.3170      0.601      0.527      0.598      -0.862       1.496
# genre[T.['Horror', 'Mystery']]                       0.6494      0.650      0.998      0.318      -0.626       1.925
# genre[T.['Horror', 'Sci-Fi', 'Thriller']]           -0.4333      0.678     -0.639      0.523      -1.763       0.896
# genre[T.['Horror', 'Sci-Fi']]                       -0.7473      0.777     -0.961      0.337      -2.271       0.777
# genre[T.['Horror', 'Thriller']]                     -0.4178      0.593     -0.705      0.481      -1.580       0.744
# genre[T.['Horror']]                                 -0.2917      0.619     -0.472      0.637      -1.505       0.921
# genre[T.['Musical', 'Romance']]                     -6.3411      1.982     -3.199      0.001     -10.227      -2.455
# genre[T.['Musical']]                                -3.4356      1.982     -1.733      0.083      -7.321       0.450
# genre[T.['Mystery', 'Romance', 'Thriller']]         -2.0010      1.982     -1.010      0.313      -5.887       1.885
# genre[T.['Mystery', 'Sci-Fi', 'Thriller']]           0.7177      1.229      0.584      0.559      -1.692       3.128
# genre[T.['Mystery', 'Thriller']]                     0.5981      0.815      0.733      0.463      -1.000       2.197
# genre[T.['Romance', 'Sci-Fi']]                       0.5252      1.982      0.265      0.791      -3.361       4.411
# genre[T.['Romance', 'Thriller']]                    -5.3972      1.982     -2.723      0.006      -9.283      -1.511
# genre[T.['Romance']]                                -0.7662      1.454     -0.527      0.598      -3.618       2.085
# genre[T.['Sci-Fi', 'Thriller']]                     -0.2503      1.014     -0.247      0.805      -2.238       1.737
# genre[T.['Thriller']]                               -0.9723      0.840     -1.158      0.247      -2.619       0.674
# genre[T.['Western']]                                 0.9944      1.014      0.981      0.327      -0.993       2.982
# ==============================================================================
# Omnibus:                     1046.783   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2904.207
# Skew:                          -1.102   Prob(JB):                         0.00
# Kurtosis:                       6.006   Cond. No.                         391.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Again, the R squred is much higher! It  is better to use to original genre.

# %% [markdown]
# ### Boxplots

# %%
budget, revenue, rating = list(), list(), list()
for genre in genre_names:
    budget.append(data[data[genre] == 1]['log_budget'])
    revenue.append(data[data[genre] == 1]['log_revenue'])
    rating.append(data[data[genre] == 1]['averageRating'])

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 3, figsize=(18,6))
axs[0].boxplot(budget, labels=genre_names, vert = False)
axs[0].set_xlabel('log budget')
axs[1].boxplot(revenue, labels=genre_names, vert = False)
axs[1].set_xlabel('log revenue')
axs[2].boxplot(rating, labels=genre_names, vert = False)
axs[2].set_xlabel('rating')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Useful ?

# %% [markdown]
# ### 4) Low budget and high revenue
# #### Scatter plot

# %% [markdown]
# Let's try to look at region where the budget il low and the revenue is high.
# For this we use a linear regression and we select a threshold for detecting the low budget.

# %%
mod = smf.ols(formula="log_revenue ~ log_budget ", data=data)
res = mod.fit()

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log_revenue   R-squared:                       0.276
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     1916.
# Date:                Wed, 07 Dec 2022   Prob (F-statistic):               0.00
# Time:                        16:56:55   Log-Likelihood:                -9825.9
# No. Observations:                5018   AIC:                         1.966e+04
# Df Residuals:                    5016   BIC:                         1.967e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.1076      0.260     23.472      0.000       5.598       6.618
# log_budget     0.6687      0.015     43.770      0.000       0.639       0.699
# ==============================================================================
# Omnibus:                      948.786   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5696.397
# Skew:                          -0.767   Prob(JB):                         0.00
# Kurtosis:                       7.989   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
coef = res.params.values

# %%
fig = sns.scatterplot(data.log_budget,data.log_revenue)
fig.axline((0,coef[0]), slope=coef[1], color='red', label='Linear fit',linestyle='dashed')
plt.show()
# Out:
# C:\Users\lisap\anaconda3\envs\IPLAB\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Let's select the movies with log budget lower than 7.
# In this region we see that all the movies are above the regression line, therefore they have a quite high revenue compared to the budget.

# %%
low_budget = data.loc[data.log_budget <= 7]

# %%
df = low_budget.copy()
df = df.drop(columns = ['genre','averageRating','corr_budget','corr_revenue','log_revenue','log_budget'])

# %%
genres = df.columns
tot = []
for gen in genres:
    tot.append(sum(df[gen]))
plt.figure(figsize=(15,8))
ax = sns.barplot(x=tot, y=genres).set(title='Genres with log budget <= 7')
plt.show()

# %% [markdown]
# Above we see a representation of the genre in the case of low budget.
# There are a lot of drama movies, this could be due by the fact that there are a lot of drama movies in the datset.
# By dividing the values here by the total number of movie sin each categories we should see a bit better the situation.

# %%
all_tot = []
for gen in genres:
    all_tot.append(sum(data[gen]))

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(x=np.array(tot)/np.array(all_tot), y=genres).set(title='Genres low budget ratio all')
plt.show()

# %% [markdown]
# Now it seems that documentary and western are quite present in this low budget region.

# %% [markdown]
# We focused on low budget movies but now we can also try to look at movies that earn 10 times more than their budget.

# %%
high_revenue = data.loc[data.log_revenue >= (np.log(10) + data.log_budget)]
#high_revenue = data.copy()

# %%
df = high_revenue.copy()
df = df.drop(columns = ['genre','averageRating','corr_budget','corr_revenue','log_revenue','log_budget'])

# %%
genres = df.columns
tot = []
for gen in genres:
    tot.append(sum(df[gen]))
plt.figure(figsize=(15,8))
ax = sns.barplot(x=tot, y=genres).set(title='Genres with revunue 10 times bigger than budget')
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(x=np.array(tot)/np.array(all_tot), y=genres).set(title='Genres with revunue 10 times bigger that budget ratio all')
plt.show()

# %% [markdown]
# Among these super revenue movies there are adult and news movies.
# Actually all the movies in the category adult, only 2 unfortunately, have very low budget and very high revenue.
# The same happens for the news movie.
# We also remark that documentary shows this pattern, but with less strenght.
